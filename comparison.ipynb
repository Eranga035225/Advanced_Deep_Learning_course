# %% [markdown]
# <a href="https://colab.research.google.com/github/Eranga035225/Advanced_Deep_Learning_course/blob/main/comparison.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf

# %%
import time

# %%
tf.test.gpu_device_name()
# Out:
# ''

# %%
shape = 5000

np_array = np.random.uniform(size = [shape,shape])

# %%
np_array
# Out:
# array([[0.47744234, 0.2396759 , 0.62116413, ..., 0.52836208, 0.65268027,
#         0.2750156 ],
#        [0.61767028, 0.67579621, 0.72163769, ..., 0.31428032, 0.35289423,
#         0.56587714],
#        [0.76045574, 0.16420934, 0.71615518, ..., 0.35859914, 0.6970886 ,
#         0.44399473],
#        ...,
#        [0.57899953, 0.91178471, 0.46145806, ..., 0.44721105, 0.65761188,
#         0.5044104 ],
#        [0.0011332 , 0.43339918, 0.75894552, ..., 0.34452875, 0.14616001,
#         0.3945269 ],
#        [0.40614132, 0.89626454, 0.42192066, ..., 0.52140586, 0.77585164,
#         0.86215759]])
